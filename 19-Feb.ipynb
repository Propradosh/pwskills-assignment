# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a popular web framework for building web applications using Python. It is a lightweight and modular framework that is easy to use and provides flexibility for developers. Some of the advantages of using Flask are:
#
# Lightweight: Flask is a lightweight framework that does not come with any pre-built components, allowing developers to choose the components they need and avoiding any unnecessary bloat in their application.
#
# Easy to use: Flask is easy to learn and use, making it an excellent choice for beginners. It also has a simple and intuitive API that allows developers to quickly build web applications.
#
# Flexible: Flask allows developers to customize and extend the framework according to their needs. It does not impose any specific architecture or directory structure, giving developers more freedom in building their applications.
#
# Built-in development server: Flask comes with a built-in development server, making it easy to test and debug applications without the need for additional tools.
#
# Large community: Flask has a large community of developers who contribute to the framework's development and provide support to other developers. This community provides a wealth of resources, such as plugins, extensions, and documentation, that can help developers to build applications more quickly and efficiently.
#
# Overall, Flask is a powerful framework that is easy to use, flexible, and customizable. It is an excellent choice for building web applications, particularly for smaller projects or prototypes.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return '<h1>Hello World!!</h1>'

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![ice_screenshot_20230221-200955.png](attachment:50e24150-2db6-4110-8620-0ad70590cdac.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# In Flask, app routing refers to the process of mapping URLs to specific functions or views in a Flask application. When a user makes a request to a specific URL, the Flask application uses the URL mapping to determine which view function should be executed to handle the request.
#
# We use app routes in Flask for several reasons:
#
# To handle different types of HTTP requests: Flask provides decorators such as @app.route() to handle GET, POST, PUT, DELETE, and other HTTP requests. By using app routes, we can define separate functions for each type of request.
#
# To organize application code: App routing allows us to structure our Flask application in a logical and organized way by grouping related views together.
#
# To provide dynamic content: App routes can also be used to provide dynamic content by accepting variables as part of the URL. For example, we could define a route that accepts a user ID as a variable, and then use that variable to display information about the user.
#
# To create REST-ful APIs: App routing is an essential part of creating RESTful APIs in Flask. By mapping URLs to specific functions, we can define the various endpoints for our API and handle requests to those endpoints appropriately.
#
# Overall, app routing is a powerful feature of Flask that allows developers to build flexible and scalable web applications. By mapping URLs to specific functions, we can handle different types of requests, organize our code, provide dynamic content, and create RESTful APIs.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def company_details():
    return "<h1>Company Name: ABC Corporation</h1><br><h1>Location: India</h1><br><h1>Contact Detail: 999-999-9999</h1>"

@app.route("/welcome")
def welcome_msg():
    return "<h1>Welcome to ABC Corporation</h1>"


if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![ice_screenshot_20230221-202139.png](attachment:d2a2e8c9-b490-4fc4-b46b-4246f40385b5.png)![ice_screenshot_20230221-202049.png](attachment:fc09ec9a-64d0-4e71-b402-0aad436c8911.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# In Flask, the url_for() function is used for URL building. It generates a URL to the given endpoint with the method provided.
#
# Here's an example Python code that demonstrates the usage of url_for() function in Flask:

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return 'Hello, World!'

@app.route('/user/<username>')
def profile(username):
    return f'Hello, {username}!'

@app.route('/about')
def about():
    return 'About page'

with app.test_request_context():
    print(url_for('index')) 
    print(url_for('profile', username='Pradosh'))  
    print(url_for('about'))
